# %%
# Add dependencies
import glob
import pandas as pd

# %%
# Combine all the csv data into a new csv

clean_data = pd.concat([pd.read_csv(f) for f in glob.glob('citibike_data/*.csv')], ignore_index = True)

# %%
# Display results
clean_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
# Get a count of the data in each column to see if they match
clean_data.count()
# Out:
# tripduration               336802
# starttime                  336802
# stoptime                   336802
# start station id           336802
# start station name         336802
# start station latitude     336802
# start station longitude    336802
# end station id             336802
# end station name           336802
# end station latitude       336802
# end station longitude      336802
# bikeid                     336802
# usertype                   336802
# birth year                 336802
# gender                     336802
# dtype: int64

# %%
# 
clean_data.gender[clean_data.gender == 0] = 'unknown'
clean_data.gender[clean_data.gender == 1] = 'male'
clean_data.gender[clean_data.gender == 2] = 'female'
clean_data.head()
# Out:
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# ...

# %%
# Export to csv
clean_data.to_csv('clean_data/cleandata2020.csv', mode = 'w', index=False)

# %%
# Import Data
Data_To_Load1 = "citibike_data/JC-202001-citibike-tripdata.csv"

january_data = pd.read_csv(Data_To_Load1)

# %%
january_data.max()
# Out:
# tripduration                                 520598
# starttime                  2020-01-31 23:48:35.1700
# stoptime                   2020-02-01 00:00:36.4060
# start station id                               3792
# start station name                          York St
# start station latitude                      40.7487
# start station longitude                    -74.0321
# end station id                                 3792
# end station name                            York St
# end station latitude                        40.7559
# end station longitude                      -74.0021
# bikeid                                        42370
# usertype                                 Subscriber
# birth year                                     2002
# gender                                            2
# dtype: object

# %%
january_data['birth year'].min()
# Out:
# 1888

# %%
january_data['tripduration'].median()
# Out:
# 326.0

# %%
january_data['birth year'].head()
# Out:
# 0    1984
# 1    1989
# 2    1989
# 3    1969
# 4    1983
# Name: birth year, dtype: int64

# %%
birthyearsort = january_data.sort_values('birth year', ascending = True)
birthyearsort.head()
# Out:
#        tripduration                 starttime                  stoptime  \
# 6682             97  2020-01-09 17:45:17.0690  2020-01-09 17:46:54.3580
# 11171            82  2020-01-14 07:32:59.8460  2020-01-14 07:34:22.4420
# 22827           115  2020-01-28 19:19:42.9670  2020-01-28 19:21:38.5720
# 17155            89  2020-01-22 07:52:17.4500  2020-01-22 07:53:46.8910
# 7949            105  2020-01-10 19:20:29.7050  2020-01-10 19:22:14.8400
#
#        start station id start station name  start station latitude  \
# 6682               3187          Warren St               40.721124
# 11171              3275     Columbus Drive               40.718355
# 22827              3187          Warren St               40.721124
# 17155              3275     Columbus Drive               40.718355
# 7949               3187          Warren St               40.721124
#
#        start station longitude  end station id end station name  \
# ...

# %%
january_data.loc[january_data['birth year'] < 1919]
# Out:
#        tripduration                 starttime                  stoptime  \
# 2667            141  2020-01-05 09:38:17.6380  2020-01-05 09:40:39.6170
# 3193             74  2020-01-06 07:36:38.4470  2020-01-06 07:37:52.7620
# 6682             97  2020-01-09 17:45:17.0690  2020-01-09 17:46:54.3580
# 7949            105  2020-01-10 19:20:29.7050  2020-01-10 19:22:14.8400
# 11171            82  2020-01-14 07:32:59.8460  2020-01-14 07:34:22.4420
# 12788            95  2020-01-15 17:47:12.3450  2020-01-15 17:48:48.1690
# 13255            80  2020-01-16 07:34:13.8290  2020-01-16 07:35:34.4480
# 14074            78  2020-01-16 19:33:28.1540  2020-01-16 19:34:46.1840
# 14904           103  2020-01-17 20:21:52.5510  2020-01-17 20:23:35.9350
# 17155            89  2020-01-22 07:52:17.4500  2020-01-22 07:53:46.8910
# 18147           102  2020-01-23 07:47:58.8340  2020-01-23 07:49:41.6230
# 21789           100  2020-01-27 19:13:42.6940  2020-01-27 19:15:22.9310
# ...

# %%
januaryBY = january_data.drop(january_data[january_data['birth year'] < 1919].index)

januaryBY['birth year'].min()
# Out:
# 1938

# %%
januaryBY['tripduration'].max()
# Out:
# 520598

# %%
januaryBY.loc[januaryBY['tripduration'] > 15000]
# Out:
#        tripduration                 starttime                  stoptime  \
# 1300          16693  2020-01-03 06:46:45.3900  2020-01-03 11:24:58.6010
# 3023         132652  2020-01-05 18:49:09.4650  2020-01-07 07:40:01.6080
# 3053          40062  2020-01-05 19:59:58.7330  2020-01-06 07:07:41.0580
# 8722          72633  2020-01-11 14:58:56.3100  2020-01-12 11:09:29.6290
# 8772         190093  2020-01-11 15:23:33.9060  2020-01-13 20:11:47.3170
# 8784          61879  2020-01-11 15:28:52.8780  2020-01-12 08:40:12.0120
# 8839          24706  2020-01-11 16:14:08.6080  2020-01-11 23:05:54.7500
# 9324          22822  2020-01-12 09:54:35.9770  2020-01-12 16:14:58.8640
# 9588          75091  2020-01-12 13:26:03.3350  2020-01-13 10:17:35.0480
# 9682         150034  2020-01-12 14:30:53.2630  2020-01-14 08:11:27.5000
# 10047         68852  2020-01-12 20:19:08.4850  2020-01-13 15:26:41.0380
# 14923        152783  2020-01-17 21:44:00.7060  2020-01-19 16:10:23.9770
# ...

# %%
januaryClean = januaryBY.drop(januaryBY[januaryBY['tripduration'] > 15000].index)

januaryClean['tripduration'].max()
# Out:
# 14984

# %%
januaryClean.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  25986.000000      25986.000000            25986.000000
# mean     463.273493       3305.614369               40.722576
# std      579.684591        184.042670                0.006671
# min       61.000000       3184.000000               40.711130
# 25%      225.000000       3195.000000               40.718355
# 50%      326.000000       3211.000000               40.721525
# 75%      501.000000       3276.000000               40.726012
# max    14984.000000       3792.000000               40.748716
#
#        start station longitude  end station id  end station latitude  \
# count             25986.000000    25986.000000          25986.000000
# mean                -74.046603     3305.262141             40.722259
# std                   0.010981      186.661252              0.006523
# min                 -74.083639      525.000000             40.709651
# ...

# %%
januaryClean['stoptime'].min()
# Out:
# '2020-01-01 00:08:37.0370'

# %%
januaryClean['stoptime'].max()
# Out:
# '2020-02-01 00:00:36.4060'

# %%
januaryClean['starttime'].min()
# Out:
# '2020-01-01 00:04:50.1920'

# %%
januaryClean['starttime'].max()
# Out:
# '2020-01-31 23:48:35.1700'

# %%
januaryClean['starttime'] = pd.to_datetime(januaryClean.starttime)
januaryClean.info('starttime')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25986 entries, 0 to 26019
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             25986 non-null  int64
#  1   starttime                25986 non-null  datetime64[ns]
#  2   stoptime                 25986 non-null  object
#  3   start station id         25986 non-null  int64
#  4   start station name       25986 non-null  object
#  5   start station latitude   25986 non-null  float64
#  6   start station longitude  25986 non-null  float64
#  7   end station id           25986 non-null  int64
#  8   end station name         25986 non-null  object
#  9   end station latitude     25986 non-null  float64
#  10  end station longitude    25986 non-null  float64
#  11  bikeid                   25986 non-null  int64
#  12  usertype                 25986 non-null  object
#  13  birth year               25986 non-null  int64
# ...

# %%
januaryClean['stoptime'] = pd.to_datetime(januaryClean.stoptime)
januaryClean.info('stoptime')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25986 entries, 0 to 26019
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             25986 non-null  int64
#  1   starttime                25986 non-null  datetime64[ns]
#  2   stoptime                 25986 non-null  datetime64[ns]
#  3   start station id         25986 non-null  int64
#  4   start station name       25986 non-null  object
#  5   start station latitude   25986 non-null  float64
#  6   start station longitude  25986 non-null  float64
#  7   end station id           25986 non-null  int64
#  8   end station name         25986 non-null  object
#  9   end station latitude     25986 non-null  float64
#  10  end station longitude    25986 non-null  float64
#  11  bikeid                   25986 non-null  int64
#  12  usertype                 25986 non-null  object
# ...

# %%
januaryClean.gender[januaryClean.gender == 0] = 'unknown'
januaryClean.gender[januaryClean.gender == 1] = 'male'
januaryClean.gender[januaryClean.gender == 2] = 'female'
januaryClean
# Out:
# C:\Users\Kim\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        tripduration               starttime                stoptime  \
# 0               226 2020-01-01 00:04:50.192 2020-01-01 00:08:37.037
# 1               377 2020-01-01 00:16:01.670 2020-01-01 00:22:19.080
# 2               288 2020-01-01 00:17:33.877 2020-01-01 00:22:22.442
# 3               435 2020-01-01 00:32:05.902 2020-01-01 00:39:21.066
# 4               231 2020-01-01 00:46:19.678 2020-01-01 00:50:11.344
# ...             ...                     ...                     ...
# 26015           544 2020-01-31 23:29:29.391 2020-01-31 23:38:33.691
# ...

# %%
from datetime import datetime as dt
dayOfWeek = januaryClean.starttime.dt.day_name()
januaryClean['dayOfWeek'] = dayOfWeek
januaryClean
# Out:
#        tripduration               starttime                stoptime  \
# 0               226 2020-01-01 00:04:50.192 2020-01-01 00:08:37.037
# 1               377 2020-01-01 00:16:01.670 2020-01-01 00:22:19.080
# 2               288 2020-01-01 00:17:33.877 2020-01-01 00:22:22.442
# 3               435 2020-01-01 00:32:05.902 2020-01-01 00:39:21.066
# 4               231 2020-01-01 00:46:19.678 2020-01-01 00:50:11.344
# ...             ...                     ...                     ...
# 26015           544 2020-01-31 23:29:29.391 2020-01-31 23:38:33.691
# 26016           122 2020-01-31 23:30:59.367 2020-01-31 23:33:01.687
# 26017           201 2020-01-31 23:42:34.846 2020-01-31 23:45:55.878
# 26018           300 2020-01-31 23:45:00.680 2020-01-31 23:50:00.874
# 26019           721 2020-01-31 23:48:35.170 2020-02-01 00:00:36.406
#
#        start station id          start station name  start station latitude  \
# ...

# %%
#januaryClean.to_csv('Clean_Data/januaryCBClean.csv', mode = 'w', index=False)

# %%
# Import Data
Data_To_Load2 = "citibike_data/JC-202003-citibike-tripdata.csv"

march_data = pd.read_csv(Data_To_Load2)

# %%
march_data.describe()

# %%
march_data.info()

# %%
march_data.shape

# %%
march_data.gender.value_counts(dropna=False)

# %%
march_data.usertype.value_counts(dropna=False)

# %%
march_data.bikeid.value_counts(dropna=False)

# %%
march_data.min()

# %%
march_data.max()

# %%
march_data['birth year'].min()

# %%
march_data['tripduration'].median()

# %%
march_data['birth year'].tail()

# %%
birthyearsort =march_clean.sort_values('birth year', ascending = True)
birthyearsort.head(100)

# %%
march_data.loc[march_clean['birth year'] < 1919]

# %%
marchBY = june_clean.drop(march_clean[march_clean['birth year'] < 1919].index)

# %%
marchBY['birth year'].min()

# %%
marchBY['birth year'].max()

# %%
marchBY.loc[marchBY['tripduration'] > 15000]

# %%
marchClean = marchBY.drop(marchBY[marchBY['tripduration'] > 15000].index)
marchClean.shape

# %%
marchClean['tripduration'].max()

# %%
marchClean.describe()

# %%
marchClean['starttime'] = pd.to_datetime(marchClean.starttime)
marchClean.info('starttime')
marchClean['stoptime'] = pd.to_datetime(marchClean.stoptime)
marchClean.info('stoptime')

# %%
marchClean.info()

# %%
marchClean.gender[marchClean.gender == 0] = 'unknown'
marchClean.gender[marchClean.gender == 1] = 'male'
marchClean.gender[marchClean.gender == 2] = 'female'
marchClean

# %%
dayOfWeek = marchClean.starttime.dt.day_name()
marchClean['dayOfWeek'] = dayOfWeek
marchClean

# %%
marchClean['starttime'].max()

# %%
marchClean['starttime'].min()

# %%
marchClean['stoptime'].max()

# %%
marchClean['stoptime'].min()

# %%
#juneClean.to_csv('Clean_Data/juneCBClean.csv', mode = 'w', index=False)

# %%
# Import Data
Data_To_Load2 = "Raw_Data/201909-citibike-tripdata.csv"

# %%
sept_clean = pd.read_csv(Data_To_Load2)
